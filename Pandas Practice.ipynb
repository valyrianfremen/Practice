# %%
import numpy as np 

#this imports the numpy package

# %%
import pandas as pd 

#this imports the pandas package

# %%
#SERIES

mydata = ['Boat', 'Car', 'Bike', 'Truck']      #created a variable and assigned a list of string data
myseries = pd.Series(mydata)                   #creating a series with the data
print(myseries)                                #printing the series to check the data type in the output
# Out:
# 0     Boat
# 1      Car
# 2     Bike
# 3    Truck
# dtype: object

# %%
mydata2 = [1,2,3,4]                             #created a variable and assigned a list of num data
myseries2 = pd.Series(mydata2)                  #creating another series with the data
print(myseries2)                                #printing the series to check the data type in the output
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
#DATAFRAME

mydfdata = [('Boat',1), ('Car',55), ('Bike',99), ('Truck',43)]     #created a list that contains both string/int values and assigned it to a variable
mydf = pd.DataFrame(mydfdata, columns = ['Thing', 'Count'])        #created a dataframe and named the columns as well
print(mydf)                                                        #printed the dataframe to check result
# Out:
#    Thing  Count
# 0   Boat      1
# 1    Car     55
# 2   Bike     99
# 3  Truck     43

# %%
mydf['Thing']        #Checking the column individually and checking the type of data in it
# Out:
# 0     Boat
# 1      Car
# 2     Bike
# 3    Truck
# Name: Thing, dtype: object

# %%
mydf['Count']        #Checking the column individually and checking the type of data in it
# Out:
# 0     1
# 1    55
# 2    99
# 3    43
# Name: Count, dtype: int64

# %%
mydf.dtypes   #inspect all the datatypes inside a dataframe
# Out:
# Thing    object
# Count     int64
# dtype: object

# %%
##Loading a csv file downloaded from kaggle: https://www.kaggle.com/code/robikscube/pandas-introduction-youtube-tutorial/input?scriptVersionId=94752062 and reading the data that is present in it##

# %%
df = pd.read_csv(r"C:\Users\SohanBhat\Downloads\MrBeast_youtube_stats.csv")  # added r in front of path to resolve unicode error, converts normal string to raw string

# %%
df.head()    #inspected data with head function and by default it provides first 5 rows of data
# Out:
#             id                                              title  \
# 0  TQHEJj68Jew               I Got Hunted By A Real Bounty Hunter
# 1  00NgUctWoLQ                   Extreme $1,000,000 Hide And Seek
# 2          NaN                                            MrBeast
# 3  ayXxwJJId_c  I Bought The World&#39;s Largest Mystery Box! ...
# 4  cExLQ1o2pDw                    First To Rob Bank Wins $100,000
#
#                                          description  \
# 0  Sign up for Current w/ my Creator Code "BEAST"...
# 1  I didn't expect that to happen at the end I wa...
# 2  Accomplishments - Raised $20000000 To Plant 20...
# 3  I cant believe I spent over $500000 on mystery...
# 4  I didnt think he would actually rob the bank.....
#
#                  publishTime     kind_stats  duration_seconds    viewCount  \
# 0  2021-04-24 20:00:00+00:00  youtube#video               861   84717282.0
# 1  2021-12-18 21:00:00+00:00  youtube#video               729   32090178.0
# ...

# %%
df.head(10)  #inspected data with head function to check the first 10 rows
# Out:
#             id                                              title  \
# 0  TQHEJj68Jew               I Got Hunted By A Real Bounty Hunter
# 1  00NgUctWoLQ                   Extreme $1,000,000 Hide And Seek
# 2          NaN                                            MrBeast
# 3  ayXxwJJId_c  I Bought The World&#39;s Largest Mystery Box! ...
# 4  cExLQ1o2pDw                    First To Rob Bank Wins $100,000
# 5  GLoeAJUcz38                 Press This Button To Win $100,000!
# 6  nM89Wl03Q4g   I Survived 50 Hours In A Maximum Security Prison
# 7  9bqk6ZUsKyA                      I Spent 50 Hours Buried Alive
# 8  HBMmK1c44sE              I Spent 24 Hours In A Doomsday Bunker
# 9  vp5sSqyZ5Go  I Filled My Brother’s House With Slime &amp; B...
#
#                                          description  \
# 0  Sign up for Current w/ my Creator Code "BEAST"...
# 1  I didn't expect that to happen at the end I wa...
# 2  Accomplishments - Raised $20000000 To Plant 20...
# ...

# %%
df.tail()  # by default tail function checks the bottom 5 rows
# Out:
#               id                                              title  \
# 242  yeHjsYQ076A                         Remember When COD Was Fun?
# 243  X7doE4h6W64                  Insane Gun Sync - 7 Hours To Make
# 244  AIytwdufwW8   MY MESSAGE TO COD YOUTUBERS (Watch till end plz)
# 245  56OkH6ocYZU    L0114R - Biblical Creeper Post for Post @L0114R
# 246  zi7tZ-2PhLk  How Much Money Do You Make As An Uber Driver??...
#
#                                            description  \
# 242  Yup, another very pointless video ▻ Subscribe?...
# 243  Look at this - http://gyazo.com/8852509d2350db...
# 244  The beginning of the video is a little off top...
# 245  His channel - https://www.youtube.com/user/the...
# 246  In this video I talk about being an uber drive...
#
#                    publishTime     kind_stats  duration_seconds  viewCount  \
# 242  2015-04-26 21:26:36+00:00  youtube#video               216    16312.0
# ...

# %%
df.tail(10)      #checked the bottom 10 rows with tail function
# Out:
#               id                                              title  \
# 237  dPxAFqs2eYE  Epic Ghost Multiplayer EasterEggs! (PrisonBrea...
# 238  moMJjt5KECc                                     Money Problems
# 239  HuLAAXZXIy0                       This Kid Should Quit COD....
# 240  NiqkH7qVW0U                       100k Subs With No Videos????
# 241  uUIlb2rpIuY           Epic Minecraft city! (w/ download link!)
# 242  yeHjsYQ076A                         Remember When COD Was Fun?
# 243  X7doE4h6W64                  Insane Gun Sync - 7 Hours To Make
# 244  AIytwdufwW8   MY MESSAGE TO COD YOUTUBERS (Watch till end plz)
# 245  56OkH6ocYZU    L0114R - Biblical Creeper Post for Post @L0114R
# 246  zi7tZ-2PhLk  How Much Money Do You Make As An Uber Driver??...
#
#                                            description  \
# 237  These are three eastereggs I found in Ghost......
# 238  This is a little different of a video and I ju...
# ...

# %%
df.dtypes   # this shows what type of data is present in each of the series of the dataframe that we are working with
# Out:
# id                                        object
# title                                     object
# description                               object
# publishTime                               object
# kind_stats                                object
# duration_seconds                           int64
# viewCount                                float64
# likeCount                                float64
# commentCount                             float64
# thumbnails.default.url                    object
# thumbnails.default.width                 float64
# thumbnails.default.height                float64
# thumbnails.medium.url                     object
# thumbnails.medium.width                  float64
# thumbnails.medium.height                 float64
# thumbnails.high.url                       object
# thumbnails.high.width                    float64
# thumbnails.high.height                   float64
# contentDetails.duration                   object
# ...

# %%
df.describe()   # describe works on the columns that contain numbers and provides some key stats as output
# Out:
#        duration_seconds     viewCount     likeCount   commentCount  \
# count        247.000000  2.460000e+02  2.440000e+02     245.000000
# mean        1886.234818  5.084638e+07  1.610498e+06   75562.783673
# std         8642.188728  4.062672e+07  1.879529e+06   85356.537127
# min            0.000000  1.395400e+04  3.700000e+02      59.000000
# 25%          425.500000  1.406442e+07  4.348780e+05   21552.000000
# 50%          776.000000  4.904782e+07  1.358232e+06   60701.000000
# 75%          923.000000  8.125392e+07  2.294378e+06   99670.000000
# max        85686.000000  1.787632e+08  1.904943e+07  726861.000000
#
#        thumbnails.default.width  thumbnails.default.height  \
# count                     246.0                      246.0
# mean                      120.0                       90.0
# std                         0.0                        0.0
# min                       120.0                       90.0
# 25%                       120.0                       90.0
# ...

# %%
df['viewCount'] #looking at a specific column in the dataframe
# Out:
# 0       84717282.0
# 1       32090178.0
# 2              NaN
# 3      101745632.0
# 4       50008942.0
#           ...
# 242        16312.0
# 243        15740.0
# 244        18502.0
# 245        16627.0
# 246        18773.0
# Name: viewCount, Length: 247, dtype: float64

# %%
df.loc[4] # looking at a specific row using loc
# Out:
# id                                                                             cExLQ1o2pDw
# title                                                      First To Rob Bank Wins $100,000
# description                              I didnt think he would actually rob the bank.....
# publishTime                                                      2021-09-26 20:00:06+00:00
# kind_stats                                                                   youtube#video
# duration_seconds                                                                       482
# viewCount                                                                       50008942.0
# likeCount                                                                        2359606.0
# commentCount                                                                      120621.0
# thumbnails.default.url                      https://i.ytimg.com/vi/cExLQ1o2pDw/default.jpg
# ...

# %%
df
# Out:
#               id                                              title  \
# 0    TQHEJj68Jew               I Got Hunted By A Real Bounty Hunter
# 1    00NgUctWoLQ                   Extreme $1,000,000 Hide And Seek
# 2            NaN                                            MrBeast
# 3    ayXxwJJId_c  I Bought The World&#39;s Largest Mystery Box! ...
# 4    cExLQ1o2pDw                    First To Rob Bank Wins $100,000
# ..           ...                                                ...
# 242  yeHjsYQ076A                         Remember When COD Was Fun?
# 243  X7doE4h6W64                  Insane Gun Sync - 7 Hours To Make
# 244  AIytwdufwW8   MY MESSAGE TO COD YOUTUBERS (Watch till end plz)
# 245  56OkH6ocYZU    L0114R - Biblical Creeper Post for Post @L0114R
# 246  zi7tZ-2PhLk  How Much Money Do You Make As An Uber Driver??...
#
#                                            description  \
# 0    Sign up for Current w/ my Creator Code "BEAST"...
# ...

# %%
df
# Out:
#                                                          title  \
# id
# TQHEJj68Jew               I Got Hunted By A Real Bounty Hunter
# 00NgUctWoLQ                   Extreme $1,000,000 Hide And Seek
# NaN                                                    MrBeast
# ayXxwJJId_c  I Bought The World&#39;s Largest Mystery Box! ...
# cExLQ1o2pDw                    First To Rob Bank Wins $100,000
# ...                                                        ...
# yeHjsYQ076A                         Remember When COD Was Fun?
# X7doE4h6W64                  Insane Gun Sync - 7 Hours To Make
# AIytwdufwW8   MY MESSAGE TO COD YOUTUBERS (Watch till end plz)
# 56OkH6ocYZU    L0114R - Biblical Creeper Post for Post @L0114R
# zi7tZ-2PhLk  How Much Money Do You Make As An Uber Driver??...
#
#                                                    description  \
# id
# TQHEJj68Jew  Sign up for Current w/ my Creator Code "BEAST"...
# 00NgUctWoLQ  I didn't expect that to happen at the end I wa...
# ...

# %%
df # used df= df.set_index('id')  to change the index column of the dataframe and checked the new dataframe
# Out:
#                                                          title  \
# id
# TQHEJj68Jew               I Got Hunted By A Real Bounty Hunter
# 00NgUctWoLQ                   Extreme $1,000,000 Hide And Seek
# NaN                                                    MrBeast
# ayXxwJJId_c  I Bought The World&#39;s Largest Mystery Box! ...
# cExLQ1o2pDw                    First To Rob Bank Wins $100,000
# ...                                                        ...
# yeHjsYQ076A                         Remember When COD Was Fun?
# X7doE4h6W64                  Insane Gun Sync - 7 Hours To Make
# AIytwdufwW8   MY MESSAGE TO COD YOUTUBERS (Watch till end plz)
# 56OkH6ocYZU    L0114R - Biblical Creeper Post for Post @L0114R
# zi7tZ-2PhLk  How Much Money Do You Make As An Uber Driver??...
#
#                                                    description  \
# id
# TQHEJj68Jew  Sign up for Current w/ my Creator Code "BEAST"...
# 00NgUctWoLQ  I didn't expect that to happen at the end I wa...
# ...

# %%
df.loc['cExLQ1o2pDw']  # using loc to check a specific row after changing our index of the dataframe
# Out:
# title                                                      First To Rob Bank Wins $100,000
# description                              I didnt think he would actually rob the bank.....
# publishTime                                                      2021-09-26 20:00:06+00:00
# kind_stats                                                                   youtube#video
# duration_seconds                                                                       482
# viewCount                                                                       50008942.0
# likeCount                                                                        2359606.0
# commentCount                                                                      120621.0
# thumbnails.default.url                      https://i.ytimg.com/vi/cExLQ1o2pDw/default.jpg
# thumbnails.default.width                                                             120.0
# ...

# %%
df.columns   # this just lists out all of the columns
# Out:
# Index(['title', 'description', 'publishTime', 'kind_stats', 'duration_seconds',
#        'viewCount', 'likeCount', 'commentCount', 'thumbnails.default.url',
#        'thumbnails.default.width', 'thumbnails.default.height',
#        'thumbnails.medium.url', 'thumbnails.medium.width',
#        'thumbnails.medium.height', 'thumbnails.high.url',
#        'thumbnails.high.width', 'thumbnails.high.height',
#        'contentDetails.duration', 'contentDetails.dimension',
#        'topicDetails.topicCategories', 'snippet.defaultLanguage',
#        'localizations.en.title', 'localizations.en.description',
#        'snippet.tags', 'contentDetails.contentRating.ytRating'],
#       dtype='object')

# %%
#Subsetting data in pandas

# %%
df = df[['title', 'description', 'publishTime', 'duration_seconds', 'viewCount', 'likeCount', 'commentCount']]    #providing a list of columns that we want to keep in our dataframe and overwrite our dataframe

# %%
df # check overwritten dataframe to make sure we have the right columns that we wanted to have
# Out:
#                                                          title  \
# id
# TQHEJj68Jew               I Got Hunted By A Real Bounty Hunter
# 00NgUctWoLQ                   Extreme $1,000,000 Hide And Seek
# NaN                                                    MrBeast
# ayXxwJJId_c  I Bought The World&#39;s Largest Mystery Box! ...
# cExLQ1o2pDw                    First To Rob Bank Wins $100,000
# ...                                                        ...
# yeHjsYQ076A                         Remember When COD Was Fun?
# X7doE4h6W64                  Insane Gun Sync - 7 Hours To Make
# AIytwdufwW8   MY MESSAGE TO COD YOUTUBERS (Watch till end plz)
# 56OkH6ocYZU    L0114R - Biblical Creeper Post for Post @L0114R
# zi7tZ-2PhLk  How Much Money Do You Make As An Uber Driver??...
#
#                                                    description  \
# id
# TQHEJj68Jew  Sign up for Current w/ my Creator Code "BEAST"...
# 00NgUctWoLQ  I didn't expect that to happen at the end I wa...
# ...

# %%
df.head()
# Out:
#                                                          title  \
# id
# TQHEJj68Jew               I Got Hunted By A Real Bounty Hunter
# 00NgUctWoLQ                   Extreme $1,000,000 Hide And Seek
# NaN                                                    MrBeast
# ayXxwJJId_c  I Bought The World&#39;s Largest Mystery Box! ...
# cExLQ1o2pDw                    First To Rob Bank Wins $100,000
#
#                                                    description  \
# id
# TQHEJj68Jew  Sign up for Current w/ my Creator Code "BEAST"...
# 00NgUctWoLQ  I didn't expect that to happen at the end I wa...
# NaN          Accomplishments - Raised $20000000 To Plant 20...
# ayXxwJJId_c  I cant believe I spent over $500000 on mystery...
# cExLQ1o2pDw  I didnt think he would actually rob the bank.....
#
#                            publishTime  duration_seconds    viewCount  \
# id
# TQHEJj68Jew  2021-04-24 20:00:00+00:00               861   84717282.0
# ...

# %%
df.shape  #  checks the number of rows and columns in our dataframe
# Out:
# (247, 7)

# %%
#subsetting using loc

# %%
df['viewCount'] > 1000000
# Out:
# id
# TQHEJj68Jew     True
# 00NgUctWoLQ     True
# NaN            False
# ayXxwJJId_c     True
# cExLQ1o2pDw     True
#                ...
# yeHjsYQ076A    False
# X7doE4h6W64    False
# AIytwdufwW8    False
# 56OkH6ocYZU    False
# zi7tZ-2PhLk    False
# Name: viewCount, Length: 247, dtype: bool

# %%
df_subset1 = df.loc[df['viewCount'] > 1000000] #shows all rows with viewcount greater than 1000000

# %%
df_subset1
# Out:
#                                                          title  \
# id
# TQHEJj68Jew               I Got Hunted By A Real Bounty Hunter
# 00NgUctWoLQ                   Extreme $1,000,000 Hide And Seek
# ayXxwJJId_c  I Bought The World&#39;s Largest Mystery Box! ...
# cExLQ1o2pDw                    First To Rob Bank Wins $100,000
# GLoeAJUcz38                 Press This Button To Win $100,000!
# ...                                                        ...
# xWcldHxHFpo                              I Counted To 100,000!
# mGIpOtncmSM                     Saying Pewdiepie 100,000 Times
# 9CVwXBYVqVk                Counting To 200,000 (Road To A Mil)
# 2IGxSOfsBok                              I Hate Pewdiepie!!!!!
# bEIK5ni_Pzs   How Many People Get The Diamond Play Button?????
#
#                                                    description  \
# id
# TQHEJj68Jew  Sign up for Current w/ my Creator Code "BEAST"...
# 00NgUctWoLQ  I didn't expect that to happen at the end I wa...
# ...

# %%
df['viewCount'] > 1000000
# Out:
# id
# TQHEJj68Jew     True
# 00NgUctWoLQ     True
# NaN            False
# ayXxwJJId_c     True
# cExLQ1o2pDw     True
#                ...
# yeHjsYQ076A    False
# X7doE4h6W64    False
# AIytwdufwW8    False
# 56OkH6ocYZU    False
# zi7tZ-2PhLk    False
# Name: viewCount, Length: 247, dtype: bool

# %%
df.query('viewCount > 1000000') # similar to above but much simpler to query a row from a dataset
# Out:
#                                                          title  \
# id
# TQHEJj68Jew               I Got Hunted By A Real Bounty Hunter
# 00NgUctWoLQ                   Extreme $1,000,000 Hide And Seek
# ayXxwJJId_c  I Bought The World&#39;s Largest Mystery Box! ...
# cExLQ1o2pDw                    First To Rob Bank Wins $100,000
# GLoeAJUcz38                 Press This Button To Win $100,000!
# ...                                                        ...
# xWcldHxHFpo                              I Counted To 100,000!
# mGIpOtncmSM                     Saying Pewdiepie 100,000 Times
# 9CVwXBYVqVk                Counting To 200,000 (Road To A Mil)
# 2IGxSOfsBok                              I Hate Pewdiepie!!!!!
# bEIK5ni_Pzs   How Many People Get The Diamond Play Button?????
#
#                                                    description  \
# id
# TQHEJj68Jew  Sign up for Current w/ my Creator Code "BEAST"...
# 00NgUctWoLQ  I didn't expect that to happen at the end I wa...
# ...

# %%
df.viewCount
# Out:
# id
# TQHEJj68Jew     84717282.0
# 00NgUctWoLQ     32090178.0
# NaN                    NaN
# ayXxwJJId_c    101745632.0
# cExLQ1o2pDw     50008942.0
#                   ...
# yeHjsYQ076A        16312.0
# X7doE4h6W64        15740.0
# AIytwdufwW8        18502.0
# 56OkH6ocYZU        16627.0
# zi7tZ-2PhLk        18773.0
# Name: viewCount, Length: 247, dtype: float64

# %%
df.viewCount.isna() #checks for false values
# Out:
# id
# TQHEJj68Jew    False
# 00NgUctWoLQ    False
# NaN             True
# ayXxwJJId_c    False
# cExLQ1o2pDw    False
#                ...
# yeHjsYQ076A    False
# X7doE4h6W64    False
# AIytwdufwW8    False
# 56OkH6ocYZU    False
# zi7tZ-2PhLk    False
# Name: viewCount, Length: 247, dtype: bool

# %%
~df.viewCount.isna() #checks the opposite of above i.e. checks for is not null values
# Out:
# id
# TQHEJj68Jew     True
# 00NgUctWoLQ     True
# NaN            False
# ayXxwJJId_c     True
# cExLQ1o2pDw     True
#                ...
# yeHjsYQ076A     True
# X7doE4h6W64     True
# AIytwdufwW8     True
# 56OkH6ocYZU     True
# zi7tZ-2PhLk     True
# Name: viewCount, Length: 247, dtype: bool

# %%
df['viewCount'].isna()
# Out:
# id
# TQHEJj68Jew    False
# 00NgUctWoLQ    False
# NaN             True
# ayXxwJJId_c    False
# cExLQ1o2pDw    False
#                ...
# yeHjsYQ076A    False
# X7doE4h6W64    False
# AIytwdufwW8    False
# 56OkH6ocYZU    False
# zi7tZ-2PhLk    False
# Name: viewCount, Length: 247, dtype: bool

# %%
df = df.loc[~df['viewCount'].isna()]  #removed all the null values and this gives all rows corresponding to view count that are not null values and overwrite

# %%
df.dtypes
# Out:
# title                object
# description          object
# publishTime          object
# duration_seconds      int64
# viewCount           float64
# likeCount           float64
# commentCount        float64
# dtype: object

# %%
df['viewCount'] = df['viewCount'].astype('int')     #casting and changing type of data

# %%
df['publishTime'] = pd.to_datetime(df['publishTime'])

# %%
df['likeCount'].astype('str')
# Out:
# id
# TQHEJj68Jew    2876493.0
# 00NgUctWoLQ    2125183.0
# ayXxwJJId_c    3110824.0
# cExLQ1o2pDw    2359606.0
# GLoeAJUcz38    2762425.0
#                  ...
# yeHjsYQ076A        574.0
# X7doE4h6W64        637.0
# AIytwdufwW8        508.0
# 56OkH6ocYZU        430.0
# zi7tZ-2PhLk        370.0
# Name: likeCount, Length: 246, dtype: object

# %%
#create a new column

# %%
df.head()
# Out:
#                                                          title  \
# id
# TQHEJj68Jew               I Got Hunted By A Real Bounty Hunter
# 00NgUctWoLQ                   Extreme $1,000,000 Hide And Seek
# ayXxwJJId_c  I Bought The World&#39;s Largest Mystery Box! ...
# cExLQ1o2pDw                    First To Rob Bank Wins $100,000
# GLoeAJUcz38                 Press This Button To Win $100,000!
#
#                                                    description  \
# id
# TQHEJj68Jew  Sign up for Current w/ my Creator Code "BEAST"...
# 00NgUctWoLQ  I didn't expect that to happen at the end I wa...
# ayXxwJJId_c  I cant believe I spent over $500000 on mystery...
# cExLQ1o2pDw  I didnt think he would actually rob the bank.....
# GLoeAJUcz38  Push the red subscribe button and you could al...
#
#                           publishTime  duration_seconds  viewCount  likeCount  \
# id
# TQHEJj68Jew 2021-04-24 20:00:00+00:00               861   84717282  2876493.0
# ...

# %%
df['likeCount'] / df['viewCount']
# Out:
# id
# TQHEJj68Jew    0.033954
# 00NgUctWoLQ    0.066225
# ayXxwJJId_c    0.030575
# cExLQ1o2pDw    0.047184
# GLoeAJUcz38    0.018982
#                  ...
# yeHjsYQ076A    0.035189
# X7doE4h6W64    0.040470
# AIytwdufwW8    0.027456
# 56OkH6ocYZU    0.025862
# zi7tZ-2PhLk    0.019709
# Length: 246, dtype: float64

# %%
df['like_to_view_ratio'] = df['likeCount'] / df['viewCount']  # adding a new column called like_to_view_ratio

# %%
df.head()
# Out:
#                                                          title  \
# id
# TQHEJj68Jew               I Got Hunted By A Real Bounty Hunter
# 00NgUctWoLQ                   Extreme $1,000,000 Hide And Seek
# ayXxwJJId_c  I Bought The World&#39;s Largest Mystery Box! ...
# cExLQ1o2pDw                    First To Rob Bank Wins $100,000
# GLoeAJUcz38                 Press This Button To Win $100,000!
#
#                                                    description  \
# id
# TQHEJj68Jew  Sign up for Current w/ my Creator Code "BEAST"...
# 00NgUctWoLQ  I didn't expect that to happen at the end I wa...
# ayXxwJJId_c  I cant believe I spent over $500000 on mystery...
# cExLQ1o2pDw  I didnt think he would actually rob the bank.....
# GLoeAJUcz38  Push the red subscribe button and you could al...
#
#                           publishTime  duration_seconds  viewCount  likeCount  \
# id
# TQHEJj68Jew 2021-04-24 20:00:00+00:00               861   84717282  2876493.0
# ...

# %%
df.tail(0)
# Out:
# Empty DataFrame
# Columns: [title, description, publishTime, duration_seconds, viewCount, likeCount, commentCount, like_to_view_ratio]
# Index: []

# %%
df.tail(1)
# Out:
#                                                          title  \
# id
# zi7tZ-2PhLk  How Much Money Do You Make As An Uber Driver??...
#
#                                                    description  \
# id
# zi7tZ-2PhLk  In this video I talk about being an uber drive...
#
#                           publishTime  duration_seconds  viewCount  likeCount  \
# id
# zi7tZ-2PhLk 2015-05-31 18:31:25+00:00               304      18773      370.0
#
#              commentCount  like_to_view_ratio
# id
# zi7tZ-2PhLk          59.0            0.019709

# %%
df_to_append = df.tail(1)

# %%
df_to_append
# Out:
#                                                          title  \
# id
# zi7tZ-2PhLk  How Much Money Do You Make As An Uber Driver??...
#
#                                                    description  \
# id
# zi7tZ-2PhLk  In this video I talk about being an uber drive...
#
#                           publishTime  duration_seconds  viewCount  likeCount  \
# id
# zi7tZ-2PhLk 2015-05-31 18:31:25+00:00               304      18773      370.0
#
#              commentCount  like_to_view_ratio
# id
# zi7tZ-2PhLk          59.0            0.019709

# %%
df_concat = pd.concat([df, df_to_append])  #adding the last row again by creating a new row using concat

# %%
df.tail()
# Out:
#                                                          title  \
# id
# yeHjsYQ076A                         Remember When COD Was Fun?
# X7doE4h6W64                  Insane Gun Sync - 7 Hours To Make
# AIytwdufwW8   MY MESSAGE TO COD YOUTUBERS (Watch till end plz)
# 56OkH6ocYZU    L0114R - Biblical Creeper Post for Post @L0114R
# zi7tZ-2PhLk  How Much Money Do You Make As An Uber Driver??...
#
#                                                    description  \
# id
# yeHjsYQ076A  Yup, another very pointless video ▻ Subscribe?...
# X7doE4h6W64  Look at this - http://gyazo.com/8852509d2350db...
# AIytwdufwW8  The beginning of the video is a little off top...
# 56OkH6ocYZU  His channel - https://www.youtube.com/user/the...
# zi7tZ-2PhLk  In this video I talk about being an uber drive...
#
#                           publishTime  duration_seconds  viewCount  likeCount  \
# id
# yeHjsYQ076A 2015-04-26 21:26:36+00:00               216      16312      574.0
# ...

# %%
#check plots

# %%
from matplotlib import pyplot as plt

df['viewCount'].plot(kind = 'hist', bins =50, title = 'distribution of view count')
# Out:
# <Axes: title={'center': 'distribution of view count'}, ylabel='Frequency'>

# %%
#saving our output

# %%
df.to_csv('processed_data.csv')
